# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

DIR = "/content/drive/MyDrive/Competitions/Signate/MUFG2023"
INPUT_DIR = os.path.join(DIR,"input")
OUTPUT_DIR = os.path.join(DIR,"output")
OUTPUT_EXP21_DIR = DIR + '/output/EXP021/'
SUB_NUM_DIR = os.path.join(OUTPUT_DIR, 'sub_num')
OOF_DIR = os.path.join(OUTPUT_DIR, 'oof')

if not os.path.exists(OUTPUT_DIR):
    os.makedirs(OUTPUT_DIR)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# !pip install catboost
#!pip install category_encoders
#!pip install feature_engine
#!pip install featuretools
#!pip install woodwork

import lightgbm as lgb
import xgboost as xgb
from catboost import *
import catboost as ctb
from catboost import Pool
from sklearn.model_selection import StratifiedKFold, GroupKFold, StratifiedGroupKFold, KFold
from sklearn.metrics import mean_squared_error,  mean_absolute_percentage_error
from sklearn.metrics import f1_score, accuracy_score

from sklearn import preprocessing
#from category_encoders.target_encoder import TargetEncoder
#from feature_engine.encoding import WoEEncoder
#import featuretools as ft
#from woodwork.logical_types import Categorical
# Out:
# Requirement already satisfied: catboost in /usr/local/lib/python3.10/dist-packages (1.2)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.23.5)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.5.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.10.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.15.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.1.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (8.2.3)

# %%
v3_pred_df = pd.read_pickle(OUTPUT_EXP21_DIR+'oof_df.pkl')
v3_pred_df.rename(columns={"pred":"v3_pred"},inplace=True)
v3_test = pd.read_csv(os.path.join(SUB_NUM_DIR, f"submit_num_microsoft-deberta-v3-base_seed42_ver21.csv"), header=None)[1]

oof_df = pd.read_csv(os.path.join(OOF_DIR, f'oof_catboost_ver17.csv'))
oof_df.rename(columns={"pred":"oof17_pred"},inplace=True)
oof17_test = pd.read_csv(os.path.join(SUB_NUM_DIR, f"submit_num_catboost_ver17.csv"), header=None)[1]

train = pd.read_csv(os.path.join(INPUT_DIR,"train.csv"))
test = pd.read_csv(os.path.join(INPUT_DIR,"test.csv"))
card = pd.read_csv(os.path.join(INPUT_DIR, "card.csv"))
user = pd.read_csv(os.path.join(INPUT_DIR, "user.csv"))
sub = pd.read_csv(os.path.join(INPUT_DIR, "sample_submit.csv"), header=None)

# %%
numerical_features = ["amount", "cards_issued", "credit_limit", "current_age", "retirement_age", "birth_year", "latitude", "longitude",
                      "per_capita_income_zipcode", "yearly_income_person", "total_debt", "fico_score", "num_credit_cards", "income_rate"]
categorical_features = ["user_id", "card_id", "errors?", "merchant_id", "merchant_city", "merchant_state", "mcc", "use_chip",
                        "card_brand", "card_type", "has_chip", "gender", "city", "state",
                        "birth_month",
                        ]
target = "is_fraud?"

# %%
train = train.merge(oof_df[["index", "oof17_pred", "fold"]], how="left", on="index").merge(v3_pred_df[["index", "v3_pred"]], how="left", on="index")
test["oof17_pred"] = oof17_test
test["v3_pred"] = v3_test

# %%
concat_data = pd.concat([train,test],axis=0)
concat_data = concat_data.merge(card, how="left", on=["user_id", "card_id"]).merge(user, how="left", on="user_id")

concat_data = concat_data.fillna("NAN")

for col in categorical_features:
  oof17_agg = concat_data.groupby(col)["oof17_pred"].agg(["mean", "std", "max", "min"])
  oof17_agg = oof17_agg.add_prefix(f'agg17_{col}_')
  oof17_agg = oof17_agg.reset_index()

  oofv3_agg = concat_data.groupby(col)["v3_pred"].agg(["mean", "std", "max", "min"])
  oofv3_agg = oofv3_agg.add_prefix(f'aggv3_{col}_')
  oofv3_agg = oofv3_agg.reset_index()

  concat_data = concat_data.merge(oof17_agg, how="left", on=col).merge(oofv3_agg, how="left", on=col)

# %%
train_df = concat_data.iloc[:train.shape[0],:]
train_df = train_df.reset_index(drop=True)
test_df = concat_data.iloc[train.shape[0]:,:]
test_df = test_df.reset_index(drop=True)

# %%
# amount_user_mean = train_df.groupby("user_id")["amount"].mean().to_dict()
# train_df["amount_mean"] = train_df["user_id"].map(lambda x: amount_user_mean[x]).values
# test_df["amount_mean"] = test_df["user_id"].map(lambda x: amount_user_mean[x]).values
# train_df["diff_amount"] = train_df["amount"] - train_df["amount_mean"]
# test_df["diff_amount"] = test_df["amount"] - test_df["amount_mean"]

# %%
"""
train_df["neg_is_franud?"] = pd.Series(np.where(train_df[target]==1.0, 0.0, 1.0))
total_pos = train_df[target].sum()
total_neg = train_df["neg_is_franud?"].sum()

for col in categorical_features:
  print(col)
  if col=="merchant_id":
    continue
  pos = train_df.groupby(col)[target].sum() / total_pos
  neg = train_df.groupby(col)["neg_is_franud?"].sum() / total_neg
  woe = pos/neg
  train_df[f"{col}_woe"] = np.log(train_df[col].map(woe).astype(float))
  test_df[f"{col}_woe"] = np.log(test_df[col].map(woe).astype(float))
"""
# Out:
# '\ntrain_df["neg_is_franud?"] = pd.Series(np.where(train_df[target]==1.0, 0.0, 1.0))\ntotal_pos = train_df[target].sum()\ntotal_neg = train_df["neg_is_franud?"].sum()\n\nfor col in categorical_features:\n  print(col)\n  if col=="merchant_id":\n    continue\n  pos = train_df.groupby(col)[target].sum() / total_pos\n  neg = train_df.groupby(col)["neg_is_franud?"].sum() / total_neg\n  woe = pos/neg\n  train_df[f"{col}_woe"] = np.log(train_df[col].map(woe).astype(float))\n  test_df[f"{col}_woe"] = np.log(test_df[col].map(woe).astype(float))\n'

# %%
train_df[target] = train_df[target].astype(float)
corr_list = [target] + [f"agg17_{col}_mean" for col in categorical_features] + [f"aggv3_{col}_mean" for col in categorical_features]
train_df[corr_list].corr()
# Out:
#                            is_fraud?  agg17_user_id_mean  agg17_card_id_mean  \
# is_fraud?                   1.000000            0.103949            0.023271
# agg17_user_id_mean          0.103949            1.000000            0.144460
# agg17_card_id_mean          0.023271            0.144460            1.000000
# agg17_errors?_mean          0.040477           -0.034375            0.014523
# agg17_merchant_id_mean      0.592848            0.103190            0.023498
# agg17_merchant_city_mean    0.366665            0.085842            0.013075
# agg17_merchant_state_mean   0.312574            0.028388            0.000014
# agg17_mcc_mean              0.231364           -0.007549            0.011211
# agg17_use_chip_mean         0.227548            0.010817           -0.009312
# agg17_card_brand_mean       0.030013            0.119854            0.014159
# agg17_card_type_mean        0.024524            0.088930            0.043748
# agg17_has_chip_mean         0.023347            0.047695           -0.085840
# agg17_gender_mean           0.017183            0.161829            0.030886
# agg17_city_mean             0.096624            0.930673            0.150530
# agg17_state_mean            0.043678            0.416181            0.043854
# agg17_birth_month_mean      0.046291            0.447748            0.122608
# aggv3_user_id_mean          0.103763            0.990943            0.162163
# aggv3_card_id_mean          0.022988            0.152755            0.985948
# aggv3_errors?_mean          0.040477           -0.034375            0.014523
# aggv3_merchant_id_mean      0.522501            0.121148            0.030724
# aggv3_merchant_city_mean    0.366079            0.085404            0.015538
# aggv3_merchant_state_mean   0.312587            0.028226            0.001429
# aggv3_mcc_mean              0.206636           -0.013748            0.002499
# aggv3_use_chip_mean         0.227553            0.010866           -0.009251
# aggv3_card_brand_mean       0.030088            0.124472            0.019656
# aggv3_card_type_mean        0.024531            0.088735            0.044411
# aggv3_has_chip_mean         0.023347            0.047695           -0.085840
# aggv3_gender_mean           0.017183            0.161829            0.030886
# aggv3_city_mean             0.096445            0.921110            0.169124
# aggv3_state_mean            0.043183            0.407494            0.060718
# aggv3_birth_month_mean      0.046331            0.445684            0.134060
#
#                            agg17_errors?_mean  agg17_merchant_id_mean  \
# is_fraud?                            0.040477                0.592848
# agg17_user_id_mean                  -0.034375                0.103190
# agg17_card_id_mean                   0.014523                0.023498
# agg17_errors?_mean                   1.000000                0.018620
# agg17_merchant_id_mean               0.018620                1.000000
# agg17_merchant_city_mean            -0.058534                0.636314
# agg17_merchant_state_mean           -0.063434                0.554986
# agg17_mcc_mean                      -0.024691                0.406408
# agg17_use_chip_mean                 -0.093910                0.399685
# agg17_card_brand_mean                0.007289                0.026990
# agg17_card_type_mean                 0.017018                0.023222
# agg17_has_chip_mean                 -0.015513                0.025960
# agg17_gender_mean                   -0.019905                0.016651
# agg17_city_mean                     -0.025426                0.100316
# agg17_state_mean                    -0.012836                0.046080
# agg17_birth_month_mean              -0.008327                0.041704
# aggv3_user_id_mean                  -0.032472                0.102237
# aggv3_card_id_mean                   0.018434                0.022897
# aggv3_errors?_mean                   1.000000                0.018620
# aggv3_merchant_id_mean              -0.011067                0.896754
# aggv3_merchant_city_mean            -0.058681                0.631485
# aggv3_merchant_state_mean           -0.063227                0.554771
# aggv3_mcc_mean                      -0.054271                0.363320
# aggv3_use_chip_mean                 -0.093973                0.399684
# aggv3_card_brand_mean                0.007754                0.027654
# aggv3_card_type_mean                 0.017159                0.023316
# aggv3_has_chip_mean                 -0.015513                0.025960
# aggv3_gender_mean                   -0.019905                0.016651
# aggv3_city_mean                     -0.023572                0.099425
# aggv3_state_mean                    -0.013222                0.045432
# aggv3_birth_month_mean              -0.006620                0.041411
#
#                            agg17_merchant_city_mean  \
# is_fraud?                                  0.366665
# agg17_user_id_mean                         0.085842
# agg17_card_id_mean                         0.013075
# agg17_errors?_mean                        -0.058534
# agg17_merchant_id_mean                     0.636314
# agg17_merchant_city_mean                   1.000000
# agg17_merchant_state_mean                  0.871134
# agg17_mcc_mean                             0.350477
# agg17_use_chip_mean                        0.627211
# agg17_card_brand_mean                      0.005395
# agg17_card_type_mean                       0.011727
# agg17_has_chip_mean                        0.032504
# agg17_gender_mean                          0.016754
# agg17_city_mean                            0.089103
# agg17_state_mean                           0.053168
# agg17_birth_month_mean                     0.009145
# aggv3_user_id_mean                         0.083966
# aggv3_card_id_mean                         0.012769
# aggv3_errors?_mean                        -0.058534
# aggv3_merchant_id_mean                     0.834460
# aggv3_merchant_city_mean                   0.991960
# aggv3_merchant_state_mean                  0.870895
# aggv3_mcc_mean                             0.489281
# aggv3_use_chip_mean                        0.627127
# aggv3_card_brand_mean                      0.006084
# aggv3_card_type_mean                       0.011911
# aggv3_has_chip_mean                        0.032504
# aggv3_gender_mean                          0.016754
# aggv3_city_mean                            0.087029
# aggv3_state_mean                           0.053453
# aggv3_birth_month_mean                     0.007770
#
#                            agg17_merchant_state_mean  agg17_mcc_mean  \
# is_fraud?                                   0.312574        0.231364
# agg17_user_id_mean                          0.028388       -0.007549
# agg17_card_id_mean                          0.000014        0.011211
# agg17_errors?_mean                         -0.063434       -0.024691
# agg17_merchant_id_mean                      0.554986        0.406408
# agg17_merchant_city_mean                    0.871134        0.350477
# agg17_merchant_state_mean                   1.000000        0.309131
# agg17_mcc_mean                              0.309131        1.000000
# agg17_use_chip_mean                         0.718182        0.289434
# agg17_card_brand_mean                       0.000992       -0.004381
# agg17_card_type_mean                       -0.005092       -0.001675
# agg17_has_chip_mean                         0.031354        0.015971
# agg17_gender_mean                           0.030923       -0.004148
# agg17_city_mean                             0.026563       -0.005449
# agg17_state_mean                            0.039947       -0.013298
# agg17_birth_month_mean                     -0.017894        0.001690
# aggv3_user_id_mean                          0.027257       -0.010293
# aggv3_card_id_mean                         -0.001090        0.008846
# aggv3_errors?_mean                         -0.063434       -0.024691
# aggv3_merchant_id_mean                      0.732753        0.395314
# aggv3_merchant_city_mean                    0.869094        0.342814
# aggv3_merchant_state_mean                   0.999542        0.308668
# aggv3_mcc_mean                              0.479835        0.894506
# aggv3_use_chip_mean                         0.718106        0.289276
# aggv3_card_brand_mean                       0.001005       -0.002950
# aggv3_card_type_mean                       -0.004936       -0.001342
# aggv3_has_chip_mean                         0.031354        0.015971
# aggv3_gender_mean                           0.030923       -0.004148
# aggv3_city_mean                             0.025448       -0.008196
# aggv3_state_mean                            0.039693       -0.016512
# aggv3_birth_month_mean                     -0.019340       -0.000626
#
#                            agg17_use_chip_mean  agg17_card_brand_mean  ...  \
# is_fraud?                             0.227548               0.030013  ...
# agg17_user_id_mean                    0.010817               0.119854  ...
# agg17_card_id_mean                   -0.009312               0.014159  ...
# agg17_errors?_mean                   -0.093910               0.007289  ...
# agg17_merchant_id_mean                0.399685               0.026990  ...
# agg17_merchant_city_mean              0.627211               0.005395  ...
# agg17_merchant_state_mean             0.718182               0.000992  ...
# agg17_mcc_mean                        0.289434              -0.004381  ...
# agg17_use_chip_mean                   1.000000               0.005969  ...
# agg17_card_brand_mean                 0.005969               1.000000  ...
# agg17_card_type_mean                  0.001553               0.110983  ...
# agg17_has_chip_mean                   0.041365               0.053025  ...
# agg17_gender_mean                     0.022549               0.034769  ...
# agg17_city_mean                       0.006228               0.074274  ...
# agg17_state_mean                     -0.009118               0.024916  ...
# agg17_birth_month_mean               -0.022703               0.034776  ...
# aggv3_user_id_mean                    0.010012               0.129383  ...
# aggv3_card_id_mean                   -0.009100               0.014324  ...
# aggv3_errors?_mean                   -0.093910               0.007289  ...
# aggv3_merchant_id_mean                0.527154               0.025153  ...
# aggv3_merchant_city_mean              0.624292               0.005646  ...
# aggv3_merchant_state_mean             0.716357               0.000758  ...
# aggv3_mcc_mean                        0.522053              -0.007280  ...
# aggv3_use_chip_mean                   0.999994               0.006051  ...
# aggv3_card_brand_mean                 0.007637               0.998170  ...
# aggv3_card_type_mean                  0.001936               0.112795  ...
# aggv3_has_chip_mean                   0.041365               0.053025  ...
# aggv3_gender_mean                     0.022549               0.034769  ...
# aggv3_city_mean                       0.005538               0.084793  ...
# aggv3_state_mean                     -0.005403               0.029724  ...
# aggv3_birth_month_mean               -0.022459               0.039105  ...
#
#                            aggv3_merchant_state_mean  aggv3_mcc_mean  \
# is_fraud?                                   0.312587        0.206636
# agg17_user_id_mean                          0.028226       -0.013748
# agg17_card_id_mean                          0.001429        0.002499
# agg17_errors?_mean                         -0.063227       -0.054271
# agg17_merchant_id_mean                      0.554771        0.363320
# agg17_merchant_city_mean                    0.870895        0.489281
# agg17_merchant_state_mean                   0.999542        0.479835
# agg17_mcc_mean                              0.308668        0.894506
# agg17_use_chip_mean                         0.716357        0.522053
# agg17_card_brand_mean                       0.000758       -0.007280
# agg17_card_type_mean                       -0.005671       -0.005763
# agg17_has_chip_mean                         0.030236        0.025143
# agg17_gender_mean                           0.031160       -0.005609
# agg17_city_mean                             0.026479       -0.012455
# agg17_state_mean                            0.039898       -0.022793
# agg17_birth_month_mean                     -0.018585       -0.015716
# aggv3_user_id_mean                          0.028138       -0.016266
# aggv3_card_id_mean                          0.000499       -0.000457
# aggv3_errors?_mean                         -0.063227       -0.054271
# aggv3_merchant_id_mean                      0.733118        0.441961
# aggv3_merchant_city_mean                    0.869559        0.482266
# aggv3_merchant_state_mean                   1.000000        0.479001
# aggv3_mcc_mean                              0.479001        1.000000
# aggv3_use_chip_mean                         0.716282        0.521791
# aggv3_card_brand_mean                       0.000789       -0.005821
# aggv3_card_type_mean                       -0.005503       -0.005316
# aggv3_has_chip_mean                         0.030236        0.025143
# aggv3_gender_mean                           0.031160       -0.005609
# aggv3_city_mean                             0.026488       -0.014958
# aggv3_state_mean                            0.042044       -0.022953
# aggv3_birth_month_mean                     -0.019700       -0.017701
#
#                            aggv3_use_chip_mean  aggv3_card_brand_mean  \
# is_fraud?                             0.227553               0.030088
# agg17_user_id_mean                    0.010866               0.124472
# agg17_card_id_mean                   -0.009251               0.019656
# agg17_errors?_mean                   -0.093973               0.007754
# agg17_merchant_id_mean                0.399684               0.027654
# agg17_merchant_city_mean              0.627127               0.006084
# agg17_merchant_state_mean             0.718106               0.001005
# agg17_mcc_mean                        0.289276              -0.002950
# agg17_use_chip_mean                   0.999994               0.007637
# agg17_card_brand_mean                 0.006051               0.998170
# agg17_card_type_mean                  0.001557               0.119037
# agg17_has_chip_mean                   0.041644               0.054392
# agg17_gender_mean                     0.022546               0.038084
# agg17_city_mean                       0.006283               0.078301
# agg17_state_mean                     -0.009094               0.019919
# agg17_birth_month_mean               -0.022689               0.037852
# aggv3_user_id_mean                    0.010068               0.134680
# aggv3_card_id_mean                   -0.009024               0.019550
# aggv3_errors?_mean                   -0.093973               0.007754
# aggv3_merchant_id_mean                0.527158               0.026033
# aggv3_merchant_city_mean              0.624208               0.006398
# aggv3_merchant_state_mean             0.716282               0.000789
# aggv3_mcc_mean                        0.521791              -0.005821
# aggv3_use_chip_mean                   1.000000               0.007722
# aggv3_card_brand_mean                 0.007722               1.000000
# aggv3_card_type_mean                  0.001940               0.121095
# aggv3_has_chip_mean                   0.041644               0.054392
# aggv3_gender_mean                     0.022546               0.038084
# aggv3_city_mean                       0.005601               0.089593
# aggv3_state_mean                     -0.005372               0.025842
# aggv3_birth_month_mean               -0.022448               0.042564
#
#                            aggv3_card_type_mean  aggv3_has_chip_mean  \
# is_fraud?                              0.024531             0.023347
# agg17_user_id_mean                     0.088735             0.047695
# agg17_card_id_mean                     0.044411            -0.085840
# agg17_errors?_mean                     0.017159            -0.015513
# agg17_merchant_id_mean                 0.023316             0.025960
# agg17_merchant_city_mean               0.011911             0.032504
# agg17_merchant_state_mean             -0.004936             0.031354
# agg17_mcc_mean                        -0.001342             0.015971
# agg17_use_chip_mean                    0.001936             0.041365
# agg17_card_brand_mean                  0.112795             0.053025
# agg17_card_type_mean                   0.999956            -0.069638
# agg17_has_chip_mean                   -0.069089             1.000000
# agg17_gender_mean                     -0.061873            -0.014510
# agg17_city_mean                        0.098018             0.051906
# agg17_state_mean                      -0.012973             0.008198
# agg17_birth_month_mean                -0.000969            -0.083622
# aggv3_user_id_mean                     0.092250             0.036025
# aggv3_card_id_mean                     0.038423            -0.088014
# aggv3_errors?_mean                     0.017159            -0.015513
# aggv3_merchant_id_mean                 0.020677             0.027970
# aggv3_merchant_city_mean               0.011834             0.030954
# aggv3_merchant_state_mean             -0.005503             0.030236
# aggv3_mcc_mean                        -0.005316             0.025143
# aggv3_use_chip_mean                    0.001940             0.041644
# aggv3_card_brand_mean                  0.121095             0.054392
# aggv3_card_type_mean                   1.000000            -0.069089
# aggv3_has_chip_mean                   -0.069089             1.000000
# aggv3_gender_mean                     -0.061873            -0.014510
# aggv3_city_mean                        0.101270             0.039446
# aggv3_state_mean                      -0.016072             0.005473
# aggv3_birth_month_mean                 0.008287            -0.093220
#
#                            aggv3_gender_mean  aggv3_city_mean  \
# is_fraud?                           0.017183         0.096445
# agg17_user_id_mean                  0.161829         0.921110
# agg17_card_id_mean                  0.030886         0.169124
# agg17_errors?_mean                 -0.019905        -0.023572
# agg17_merchant_id_mean              0.016651         0.099425
# agg17_merchant_city_mean            0.016754         0.087029
# agg17_merchant_state_mean           0.030923         0.025448
# agg17_mcc_mean                     -0.004148        -0.008196
# agg17_use_chip_mean                 0.022549         0.005538
# agg17_card_brand_mean               0.034769         0.084793
# agg17_card_type_mean               -0.061980         0.101411
# agg17_has_chip_mean                -0.014510         0.039446
# agg17_gender_mean                   1.000000         0.127967
# agg17_city_mean                     0.131934         0.989733
# agg17_state_mean                    0.137955         0.455006
# agg17_birth_month_mean             -0.026240         0.417062
# aggv3_user_id_mean                  0.159313         0.933483
# aggv3_card_id_mean                  0.027281         0.181230
# aggv3_errors?_mean                 -0.019905        -0.023572
# aggv3_merchant_id_mean              0.020741         0.123258
# aggv3_merchant_city_mean            0.017120         0.089158
# aggv3_merchant_state_mean           0.031160         0.026488
# aggv3_mcc_mean                     -0.005609        -0.014958
# aggv3_use_chip_mean                 0.022546         0.005601
# aggv3_card_brand_mean               0.038084         0.089593
# aggv3_card_type_mean               -0.061873         0.101270
# aggv3_has_chip_mean                -0.014510         0.039446
# aggv3_gender_mean                   1.000000         0.127967
# aggv3_city_mean                     0.127967         1.000000
# aggv3_state_mean                    0.119872         0.465473
# aggv3_birth_month_mean             -0.013525         0.423734
#
#                            aggv3_state_mean  aggv3_birth_month_mean
# is_fraud?                          0.043183                0.046331
# agg17_user_id_mean                 0.407494                0.445684
# agg17_card_id_mean                 0.060718                0.134060
# agg17_errors?_mean                -0.013222               -0.006620
# agg17_merchant_id_mean             0.045432                0.041411
# agg17_merchant_city_mean           0.053453                0.007770
# agg17_merchant_state_mean          0.039693               -0.019340
# agg17_mcc_mean                    -0.016512               -0.000626
# agg17_use_chip_mean               -0.005403               -0.022459
# agg17_card_brand_mean              0.029724                0.039105
# agg17_card_type_mean              -0.015185                0.007772
# agg17_has_chip_mean                0.005473               -0.093220
# agg17_gender_mean                  0.119872               -0.013525
# agg17_city_mean                    0.437097                0.422177
# agg17_state_mean                   0.978957                0.283721
# agg17_birth_month_mean             0.290165                0.995383
# aggv3_user_id_mean                 0.435408                0.448798
# aggv3_card_id_mean                 0.072001                0.136781
# aggv3_errors?_mean                -0.013222               -0.006620
# aggv3_merchant_id_mean             0.062863                0.044359
# aggv3_merchant_city_mean           0.057357                0.008798
# aggv3_merchant_state_mean          0.042044               -0.019700
# aggv3_mcc_mean                    -0.022953               -0.017701
# aggv3_use_chip_mean               -0.005372               -0.022448
# aggv3_card_brand_mean              0.025842                0.042564
# aggv3_card_type_mean              -0.016072                0.008287
# aggv3_has_chip_mean                0.005473               -0.093220
# aggv3_gender_mean                  0.119872               -0.013525
# aggv3_city_mean                    0.465473                0.423734
# aggv3_state_mean                   1.000000                0.288126
# aggv3_birth_month_mean             0.288126                1.000000
#
# [31 rows x 31 columns]

# %%
class CFG:
  debug=False
  ver=27
  model="catboost"
  n_folds=5
  trn_fold=[0, 1, 2, 3, 4]
  seed=42
  target= target
  boosting_type="gbdt"
  early_stopping_round=50
  verbose=200

# %%
if CFG.debug:
    display(train_df.groupby('fold').size())
    train_df = train_df.sample(n=1000, random_state=0).reset_index(drop=True)
    display(train_df.groupby('fold').size())

# %%
params = {
        "n_estimators":8000,
        "learning_rate":0.05,
        'depth': 5,
        "random_state":CFG.seed,
        'colsample_bylevel': 0.50,
        'subsample': 0.80,
        'l2_leaf_reg': 3,
    }

features = [f"agg17_{col}_mean" for col in categorical_features] + [f"aggv3_{col}_mean" for col in categorical_features] + [f"agg17_{col}_std" for col in categorical_features] + [f"aggv3_{col}_std" for col in categorical_features] \
+ [f"agg17_{col}_max" for col in categorical_features] + [f"aggv3_{col}_max" for col in categorical_features] + [f"agg17_{col}_min" for col in categorical_features] + [f"aggv3_{col}_min" for col in categorical_features]
oof_df = pd.DataFrame()
test_preds = np.zeros(len(test_df))

for fold in range(CFG.n_folds):
  if fold in CFG.trn_fold:
    print("="*15,f" FOLD : {fold} ","="*15)
    train_folds = train_df[train_df['fold'] != fold].reset_index(drop=True)
    valid_folds = train_df[train_df['fold'] == fold].reset_index(drop=True)

    train_X = train_folds[features]
    valid_X = valid_folds[features]
    test_X = test_df[features]
    train_labels = train_folds[CFG.target].values
    valid_labels = valid_folds[CFG.target].values

    train_pool = Pool(train_X,
                     label=train_labels
                      )
    valid_pool = Pool(valid_X,
                    label=valid_labels
                      )

    model = ctb.CatBoostClassifier(**params)
    model.fit(train_pool,
              eval_set=[valid_pool],
              early_stopping_rounds=CFG.early_stopping_round,
              verbose=CFG.verbose,
              use_best_model=True)

    valid_folds["pred"] = model.predict_proba(valid_pool)[:, 1]
    test_preds += model.predict_proba(Pool(test_X))[:, 1]
    oof_df = pd.concat([oof_df, valid_folds])

    validy_pred = np.where(valid_folds["pred"]>0.5, 1, 0)
    scoref1 =  f1_score(valid_labels, validy_pred)
    print(f"F1 Score : {scoref1}")
    del model, train_folds, valid_folds, train_X, valid_X, test_X, train_pool, valid_pool, validy_pred
# Out:
# ===============  FOLD : 0  ===============
# 0:	learn: 0.6193599	test: 0.6192918	best: 0.6192918 (0)	total: 233ms	remaining: 31m
# 200:	learn: 0.1440629	test: 0.1446048	best: 0.1446048 (200)	total: 38.8s	remaining: 25m 5s
# 400:	learn: 0.1388369	test: 0.1404167	best: 0.1404167 (400)	total: 1m 21s	remaining: 25m 43s
# 600:	learn: 0.1353337	test: 0.1378546	best: 0.1378546 (600)	total: 2m 2s	remaining: 25m 7s
# 800:	learn: 0.1326403	test: 0.1360765	best: 0.1360765 (800)	total: 2m 43s	remaining: 24m 29s
# 1000:	learn: 0.1304926	test: 0.1347645	best: 0.1347645 (1000)	total: 3m 23s	remaining: 23m 41s
# 1200:	learn: 0.1287196	test: 0.1338047	best: 0.1338047 (1200)	total: 4m 3s	remaining: 22m 56s
# 1400:	learn: 0.1271578	test: 0.1329996	best: 0.1329982 (1398)	total: 4m 43s	remaining: 22m 17s
# 1600:	learn: 0.1258302	test: 0.1323803	best: 0.1323803 (1600)	total: 5m 24s	remaining: 21m 37s
# 1800:	learn: 0.1245888	test: 0.1318490	best: 0.1318490 (1800)	total: 6m 4s	remaining: 20m 55s
# 2000:	learn: 0.1234974	test: 0.1315201	best: 0.1315180 (1994)	total: 6m 44s	remaining: 20m 14s
# 2200:	learn: 0.1224789	test: 0.1312341	best: 0.1312329 (2192)	total: 7m 25s	remaining: 19m 34s
# 2400:	learn: 0.1215638	test: 0.1309399	best: 0.1309399 (2400)	total: 8m 7s	remaining: 18m 57s
# 2600:	learn: 0.1206610	test: 0.1307238	best: 0.1307238 (2600)	total: 8m 51s	remaining: 18m 22s
# 2800:	learn: 0.1198411	test: 0.1305719	best: 0.1305711 (2799)	total: 9m 30s	remaining: 17m 38s
# 3000:	learn: 0.1190588	test: 0.1303987	best: 0.1303987 (3000)	total: 10m 11s	remaining: 16m 57s
# 3200:	learn: 0.1183479	test: 0.1302920	best: 0.1302920 (3200)	total: 10m 52s	remaining: 16m 17s
# 3400:	learn: 0.1176244	test: 0.1301541	best: 0.1301541 (3400)	total: 11m 33s	remaining: 15m 37s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.

# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.1310163123
# bestIteration = 3689
#
# Shrink model to first 3690 iterations.
# F1 Score : 0.6271058110921826

# %%
f1score =  f1_score(oof_df[CFG.target], np.where(oof_df["pred"]>0.5,1,0))
print(f'CV F1 Score: {f1score}')
# Out:
# CV F1 Score: 0.631012622509829

# %%
best_score = 0
best_thresh = 0.5
for thresh in np.arange(0.15, 0.801, 0.01):
    thresh = np.round(thresh, 2)
    score = f1_score(oof_df[CFG.target], (oof_df["pred"]>thresh).astype(int))
    print("F1 score at threshold {0} is {1}".format(thresh, score))
    if score > best_score:
      best_score = score
      best_thresh = thresh
print()
print("best F1 score at threshold {0} is {1}".format(best_thresh, f1_score(oof_df[CFG.target], (oof_df["pred"]>best_thresh).astype(int))))
# Out:
# F1 score at threshold 0.15 is 0.6012179321067633
# F1 score at threshold 0.16 is 0.6086806247922897
# F1 score at threshold 0.17 is 0.6143008676258601
# F1 score at threshold 0.18 is 0.6202359094196852
# F1 score at threshold 0.19 is 0.6252961623040364
# F1 score at threshold 0.2 is 0.6295419097683553
# F1 score at threshold 0.21 is 0.6330299471520846
# F1 score at threshold 0.22 is 0.6362538935006483
# F1 score at threshold 0.23 is 0.6389060965475561
# F1 score at threshold 0.24 is 0.6411014288558433
# F1 score at threshold 0.25 is 0.6427464352138872
# F1 score at threshold 0.26 is 0.6451906480464459
# F1 score at threshold 0.27 is 0.6465326872666614
# F1 score at threshold 0.28 is 0.6475591359887023
# F1 score at threshold 0.29 is 0.6488589211618259
# F1 score at threshold 0.3 is 0.649265103475397
# F1 score at threshold 0.31 is 0.6497124727344834
# F1 score at threshold 0.32 is 0.6504423301619096
# F1 score at threshold 0.33 is 0.6498889711324944
# F1 score at threshold 0.34 is 0.6491629776624434
# F1 score at threshold 0.35 is 0.6490039022386527
# F1 score at threshold 0.36 is 0.6484817115251897
# F1 score at threshold 0.37 is 0.647970530998054
# F1 score at threshold 0.38 is 0.6469115922496629
# F1 score at threshold 0.39 is 0.6457742134484885
# F1 score at threshold 0.4 is 0.6453606050921487
# F1 score at threshold 0.41 is 0.6438424701593881
# F1 score at threshold 0.42 is 0.6426439385766175
# F1 score at threshold 0.43 is 0.6406298072572618
# F1 score at threshold 0.44 is 0.638702277568409
# F1 score at threshold 0.45 is 0.637021299976191
# F1 score at threshold 0.46 is 0.6358915813508138
# F1 score at threshold 0.47 is 0.634937083641747
# F1 score at threshold 0.48 is 0.6340337620279551
# F1 score at threshold 0.49 is 0.6325831977103092
# F1 score at threshold 0.5 is 0.631012622509829
# F1 score at threshold 0.51 is 0.6288601271571299
# F1 score at threshold 0.52 is 0.6269945417546262
# F1 score at threshold 0.53 is 0.624770642201835
# F1 score at threshold 0.54 is 0.6228078600103725
# F1 score at threshold 0.55 is 0.6195887445887446
# F1 score at threshold 0.56 is 0.6174379298286514
# F1 score at threshold 0.57 is 0.6150331901600937
# F1 score at threshold 0.58 is 0.6117785630153121
# F1 score at threshold 0.59 is 0.6079352546387683
# F1 score at threshold 0.6 is 0.6041683207622073
# F1 score at threshold 0.61 is 0.6016749750747757
# F1 score at threshold 0.62 is 0.597448959127191
# F1 score at threshold 0.63 is 0.5931549722362442
# F1 score at threshold 0.64 is 0.5892668669318828
# F1 score at threshold 0.65 is 0.5862659544101456
# F1 score at threshold 0.66 is 0.5813280817281063
# F1 score at threshold 0.67 is 0.5763474599013273
# F1 score at threshold 0.68 is 0.5710904901289157
# F1 score at threshold 0.69 is 0.5660369481265003
# F1 score at threshold 0.7 is 0.5619033631957703
# F1 score at threshold 0.71 is 0.5566858011143001
# F1 score at threshold 0.72 is 0.5514768290612799
# F1 score at threshold 0.73 is 0.545384664659535
# F1 score at threshold 0.74 is 0.5396491378755018
# F1 score at threshold 0.75 is 0.5322259711047669
# F1 score at threshold 0.76 is 0.5265654236108089
# F1 score at threshold 0.77 is 0.519590880220767
# F1 score at threshold 0.78 is 0.5128103364642589
# F1 score at threshold 0.79 is 0.5045877674346271
# F1 score at threshold 0.8 is 0.49440670746743787
#
# best F1 score at threshold 0.32 is 0.6504423301619096

# %%
submit = pd.read_csv(os.path.join(INPUT_DIR,"sample_submit.csv"), header=None)
pred = test_preds / CFG.n_folds
submit[1] = (pred>best_thresh).astype(int)

submit.to_csv(os.path.join(OUTPUT_DIR, f'submit_{CFG.model}_ver{CFG.ver}.csv'), index=False, header=None)
display(submit.head())

plt.hist(pred,bins=25,edgecolor='white')
plt.xlabel("Pred")
plt.show()

display(submit)
print(submit[1].value_counts())
# Out:
#         0  1
# 0  471283  0
# 1  471284  0
# 2  471285  0
# 3  471286  0
# 4  471287  0
#              0  1
# 0       471283  0
# 1       471284  0
# 2       471285  0
# 3       471286  0
# 4       471287  0
# ...        ... ..
# 457953  929236  0
# 457954  929237  0
# 457955  929238  0
# 457956  929239  0
# 457957  929240  0
#
# [457958 rows x 2 columns]
# 0    431158
# 1     26800
# Name: 1, dtype: int64

# %%
OOF_DIR = os.path.join(OUTPUT_DIR, 'oof')

if not os.path.exists(OOF_DIR):
    os.makedirs(OOF_DIR)

oof_df.to_csv(os.path.join(OOF_DIR, f'oof_{CFG.model}_ver{CFG.ver}.csv'))

# %%
plt.hist(oof_df.pred,bins=25,edgecolor='white')
plt.xlabel("Pred")
plt.show()

# %%
SUB_NUM_DIR = os.path.join(OUTPUT_DIR, 'sub_num')

if not os.path.exists(SUB_NUM_DIR):
    os.makedirs(SUB_NUM_DIR)

sub_df = pd.read_csv(os.path.join(INPUT_DIR,"sample_submit.csv"), header=None)
pred = test_preds / CFG.n_folds
sub_df[1] = pred

sub_df.to_csv(os.path.join(SUB_NUM_DIR, f'submit_num_{CFG.model}_ver{CFG.ver}.csv'), index=False, header=None)
display(sub_df.head())
# Out:
#         0         1
# 0  471283  0.019974
# 1  471284  0.027572
# 2  471285  0.092954
# 3  471286  0.292529
# 4  471287  0.008626
